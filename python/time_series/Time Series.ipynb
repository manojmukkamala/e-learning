# %% [markdown]
# ### Onion Price Prediction
#
# This is my first project on Time Series Analysis. I'm pretty new to Time Series and so I want to start with something that is easy to understand and implement.
# After a quick google search, I found https://github.com/rouseguy/TimeSeriesAnalysiswithPython.
# They provided a clean explanation and code for beginners.
# So, I decided to use thier works to understand Time Series and then start working own project.
#
# The datasets are also downloaded from their repository.

# %% [markdown]
# #### Importing the required packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### 1. Acquiring the data

# %%
# Reading the dataset

AllTables = pd.read_html('MonthWiseMarketArrivals.html', header = 0)

# %%
len(AllTables)

# %%
type(AllTables)

# %%
# Required dataset

AllTables[4].head()

# %%
df = AllTables[4]

# %%
# Dimensions of dataset

df.shape

# %%
# Column names

df.columns

# %%
# Top 5 rows

df.head()

# %%
# Various ways to display data

df["Market"].head()

# %%
df.Market.head()

# %%
df[0:5]["Market"]

# %%
df[0:5].Market

# %%
df["Market"][0:5]

# %%
df.Market[0:5]

# %% [markdown]
# ### 2. Refining the data
#
# Let us work with the dataset. We are going to implement the following actions:
# 1. Renaming the columns
# 2. Filtering rows with missing values/aggregated values
# 3. Modify the datatypes of the attributes
# 4. Generate summary statistics for the attributes

# %%
# Top 5 rows

df.head()

# %%
# Renaming the columns

df.columns = ['market', 'month', 'year', 'quantity', 'priceMin', 'priceMax', 'priceMod']

# %%
# Top Row

df.head(1)

# %%
# Datatype of individual columns in the dataset

df.dtypes

# %%
# Datatype of the dataset

type(df)

# %%
# Bottom Row

df.tail(1)

# %%
# Since the last row was an aggregated row, let us remove it from our dataset

df.drop(df.tail(1).index, inplace = True)

# %%
df.head()

# %%
df.tail()

# %%
# Datatype of each of the columns in the dataset

df.dtypes

# %%
# To display only a set of columns, we should use iloc

df.iloc[:, 4:7].head()

# %%
# Converting the datatype of columns year, quantity, priceMin, priceMax, priceMod to integer.

df.iloc[:, 2:7] = df.iloc[:, 2:7].astype(int)

# %%
df.dtypes

# %%
df.head()

# %%
# Summary statistics for numeric columns in the dataset

df.describe()

# %%
# Count of each level in the categorical varible 'market'.

df.market.value_counts().head()

# %% [markdown]
# #### Extracting the States from Market Names

# %%
df.head()

# %%
# Let's extract the states into a new column called 'state'. str.split(pat = '') splits the string according to given condition.

df['state'] = df.market.str.split(pat = '(').str[-1]

# %%
df.head()

# %%
# Similarly let's extract the city into a new column called 'city'.

df['city'] = df.market.str.split(pat = '(').str[0]

# %%
df.head()

# %%
# Let's see all the distinct states in the state column

df.state.unique()

# %%
# Let's get rid of the brace ')' in the state column.

df['state'] = df['state'].str.split(')').str[0]

# %%
df.head()

# %%
# Let's create a dataset by grouping the state and market and using count for aggregation

dfState = df.groupby(['state', 'market'], as_index = False).count()

# %%
dfState.head()

# %%
# Let's see all the distinct values in the market column

dfState.market.unique()

# %%
dfState.state.unique()

# %%
# Renaming the states to appropriate values

state_now = ['PB', 'UP', 'GUJ', 'MS', 'RAJ', 'BANGALORE', 'KNT', 'BHOPAL', 'OR',
       'BHR', 'WB', 'CHANDIGARH', 'CHENNAI', 'bellary', 'podisu', 'UTT',
       'DELHI', 'MP', 'TN', 'Podis', 'GUWAHATI', 'HYDERABAD', 'JAIPUR',
       'WHITE', 'JAMMU', 'HR', 'KOLKATA', 'AP', 'LUCKNOW', 'MUMBAI',
       'NAGPUR', 'KER', 'PATNA', 'CHGARH', 'JH', 'SHIMLA', 'SRINAGAR',
       'TRIVENDRUM']

# %%
# Renaming the states to appropriate values

state_new =['PB', 'UP', 'GUJ', 'MS', 'RAJ', 'KNT', 'KNT', 'MP', 'OR',
       'BHR', 'WB', 'CH', 'TN', 'KNT', 'TN', 'UP',
       'DEL', 'MP', 'TN', 'TN', 'ASM', 'AP', 'RAJ',
       'MS', 'JK', 'HR', 'WB', 'AP', 'UP', 'MS',
       'MS', 'KER', 'BHR', 'HR', 'JH', 'HP', 'JK',
       'KEL']

# %%
df.state = df.state.replace(state_now, state_new)

# %%
df.state.unique()

# %% [markdown]
# #### Getting the Dates

# %%
df.head()

# %%
# Let's display the index of the dataset

df.index

# %%
# to_datetime() converts the string date into numberic date format

pd.to_datetime('January 2012')

# %%
# Let's add a new column 'date' to the dataset by concatinating the month and year columns

df['date'] = df['month'] + '-' + df['year'].map(str)

# %%
df.head()

# %%
index = pd.to_datetime(df.date)

# %%
# Changing the index of the dataset into dates

df.index = pd.PeriodIndex(df.date, freq = 'M')

# %%
df.index

# %%
df.head()

# %% [markdown]
# ### 3. Exploring the data

# %%
df.dtypes

# %%
# Changing the date column to Time-interval column
# DatetimeIndex() - Immutable ndarray of datetime64 data, represented internally as int64, and which can be boxed to Timestamp objects that are subclasses of datetime and carry metadata such as frequency information.

df.date = pd.DatetimeIndex(df.date)

# %%
df.dtypes

# %%
df.head()

# %%
# Let us display the distinct cities in our dataset

pd.unique(df.city)

# %% [markdown]
# #### How Big is the Bangalore Onion Market compared to other cities in India?
#
# Let us try to do this examination for one of the year only. So we want to reduce our dataframe for only where the year = 2010.

# %%
# Creating a subset of data whose year = 2010

df2010 = df[df['year'] == 2010]

# %%
df2010.head()

# %%
# Creating another subset with data points whose city = BANGALORE and year = 2010

df2010Bang = df[(df.year == 2010) & (df.city == 'BANGALORE')]

# %%
df2010Bang

# %%
# Let's create another subset grouping by cities, aggregated by sum.

df2010City = df2010.groupby(['city']).sum()

# %%
df2010City.head()

# %%
df2010City.shape

# %%
type(df2010City)

# %%
# Let's modify the subset to include only the aggregated quantities.

df2010City = df2010.groupby(['city']).quantity.sum()

# %%
df2010City.head()

# %%
type(df2010City)

# %%
# To create a dataframe again, it is best to specify index as false

df2010City = df2010.groupby(['city'], as_index=False).quantity.sum()

# %%
df2010City.head()

# %%
sorted(df2010City.quantity)

# %%
# Sort the subset by quantity descending.

df2010City = df2010City.sort_values(by = 'quantity', ascending = False)

# %%
df2010City.head()

# %%
# %timeit sorted(df2010City.quantity)

# %%
# %timeit df2010City.quantity.sort_values()

# %%
# %timeit df2010City.sort_values(by = 'quantity', ascending = 'False')

# %%
# Set some parameters to get good visuals - style to ggplot and size to 15,10

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (20, 10)

# %%
# Plotting the quantities by cities

df2010City.plot(kind = 'barh', x = 'city', y = 'quantity')

# %% [markdown]
# #### Let's compare the size of Onion market among the Cities

# %%
# Creating a subset of data

df2010State = df2010.groupby('state', as_index = False).quantity.sum()

# %%
df2010State.head()

# %%
# Sorting

df2010State = df2010State.sort_values(by = 'quantity', ascending=False)

# %%
df2010State.head()

# %%
# Plotting

df2010State.plot(kind = 'barh', x = 'state', y = 'quantity')

# %% [markdown]
# #### Have the price variation in Onion prices in Bangalore really gone up over the years?

# %%
df.head()

# %%
# Creating a subset of data with data points whose city = 'BANGALORE'

dfBang = df[df['city'] == 'BANGALORE']

# %%
dfBang.head()

# %%
dfBang.describe()

# %%
# Rouding off the decimal values

pd.set_option('precision', 0)

# %%
dfBang.describe()

# %%
dfBang.head()

# %%
dfBang.index

# %%
# Sort the dataframe by date

dfBang = dfBang.sort_values(by = 'date')
dfBang.head()

# %%
# Plotting the modal price

dfBang.priceMod.plot()

# %%
# Plotting modal price, minimum price, maximum price

dfBang.plot(kind = 'line', y = ['priceMin', 'priceMod', 'priceMax'])

# %%
# Creating a new column by computing the difference between maximum price and minimum price

dfBang['priceDiff'] = dfBang['priceMax'] - dfBang['priceMin']

# %%
dfBang.head()

# %%
# Plotting the price difference

dfBang.plot(kind = 'line', y = 'priceDiff')

# %% [markdown]
# #### Pivot Table

# %%
# Creating a new column by computing the month

dfBang['monthVal'] = pd.DatetimeIndex(dfBang['date']).month

# %%
dfBang.head()

# %%
# Creating a Pivot table

dfBangPivot = pd.pivot_table(dfBang, values = 'priceDiff', columns = 'year', index = 'monthVal')

# %%
dfBangPivot

# %%
# Plotting the pivot table

dfBangPivot.plot()

# %%
dfBangPivot.plot(subplots = True, figsize = (15, 15), layout = (3, 5), sharey = True)

# %%
dfBangPivot.plot(subplots = True, figsize = (15, 15), layout = (3, 5), sharey = False)

# %% [markdown]
# ### 5. Model the Solution

# %%
# Import statsmodel

import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tsa.stattools import adfuller

# %%
df.head()

# %%
df = df.sort_values(by = 'date')

# %%
df.head()

# %% [markdown]
# #### Can we forecast the price of Onion in Bangalore

# %%
dfBang.head()

# %%
# Drop Redundant Columns

dfBang = dfBang.drop(['market', 'month', 'year', 'priceMin', 'priceMax', 'state', 'city', 'priceDiff', 'monthVal'], axis = 1)

# %%
dfBang.head()

# %%
dfBang.priceMod.plot()

# %%
dfBang.quantity.plot()

# %%
dfBang.priceMod.plot(kind = 'hist', bins = 30)

# %%
# Computing the log value for Modal price

dfBang['priceModLog'] = np.log(dfBang.priceMod)
dfBang.head()

# %%
dfBang['priceModLog'].plot(kind = 'hist', bins = 30)

# %%
dfBang.priceModLog.plot()

# %% [markdown]
# #### Basic Time Series Model

# %%
model_mean_pred = dfBang.priceModLog.mean()

# %%
dfBang['priceMean'] = np.exp(model_mean_pred)

# %%
dfBang.head()

# %%
dfBang.plot(kind = 'line', x = 'date', y = ['priceMod', 'priceMean'])

# %%
# We will use Root Mean Squared Error to calculate our error values

def RMSE(predicted, actual):
    mse = (predicted - actual)**2
    rmse = np.sqrt(mse.sum()/mse.count())
    return rmse

# %%
model_mean_RMSE = RMSE(dfBang.priceMean, dfBang.priceMod)
model_mean_RMSE

# %%
dfBangResults = pd.DataFrame(columns = ['Model', 'Forecast', 'RMSE'])
dfBangResults.head()

# %%
dfBangResults.loc[0, 'Model'] = "Mean"
dfBangResults.loc[0, 'Forecast'] = np.exp(model_mean_pred)
dfBangResults.loc[0, 'RMSE'] = model_mean_RMSE

# %%
dfBangResults.head()

# %% [markdown]
# #### Linear Trend Model

# %%
dfBang.head()

# %%
dfBang.dtypes

# %%
dfBang.date.min()

# %%
# Adding a new column to compute the date difference in days

dfBang['timeIndex'] = dfBang.date - dfBang.date.min()

# %%
dfBang.head()

# %%
dfBang.dtypes

# %%
dfBang['timeIndex'] = dfBang['timeIndex']/np.timedelta64(1, 'M')

# %%
dfBang.timeIndex.head()

# %%
dfBang.head()

# %%
model_linear = smf.ols('priceModLog ~ timeIndex', data = dfBang).fit()

# %%
model_linear.summary()

# %%
model_linear.params

# %%
c = model_linear.params[0]
c

# %%
m = model_linear.params[1]
m

# %%
model_linear_pred = model_linear.predict()

# %%
model_linear_pred

# %%
# Plot the prediction line
dfBang.plot(kind = 'line', x = 'timeIndex', y = 'priceModLog')
plt.plot(dfBang.timeIndex, model_linear_pred, '-')

# %%
model_linear.resid.plot(kind = 'bar')

# %% [markdown]
# **Is this a good model?**
#
# What measures can we check to see if the model is good?
#
# It is seen here (and  also evident on the regression line plot, if you look closely) that the linear trend model has a tendency to make an error of the same sign for many periods in a row. This tendency is measured in statistical terms by the **lag-1 autocorrelation and Durbin-Watson statistic**.  If there is no time pattern, the lag-1 autocorrelation should be very close to zero, and the Durbin-Watson statistic ought to be very close to 2, which is not the case here.  If the model has succeeded in extracting all the "signal" from the data, there should be no pattern at all in the errors: the error in the next period should not be correlated with any previous errors. The linear trend model obviously fails the autocorrelation test in this case.
